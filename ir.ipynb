# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from review_summary import models

# %%
users = pd.read_csv('data/yelp_academic_dataset_user.csv')

# %%
user = users[users.user_id == 'ut24uPCSJrBIB7tcaTxEvQ']

# %%
users.dtypes
# Out:
# yelping_since           object
# compliments.plain      float64
# review_count             int64
# friends                 object
# compliments.cute       float64
# compliments.writer     float64
# fans                     int64
# compliments.note       float64
# type                    object
# compliments.hot        float64
# compliments.cool       float64
# compliments.profile    float64
# average_stars          float64
# compliments.more       float64
# elite                   object
# name                    object
# user_id                 object
# votes.cool               int64
# compliments.list       float64
# votes.funny              int64
# compliments.photos     float64
# compliments.funny      float64
# votes.useful             int64
# dtype: object

# %%
user = users.iloc[1]

# %%
user.type
# Out:
# 'user'

# %%
user.user_id
# Out:
# 'rpOyqD_893cqmDAtJLbdog'

# %%
reviews = pd.read_csv('data/yelp_academic_dataset_review.csv')

# %%
review_1 = reviews[reviews.business_id == '6TPxhpHqFedjMvBuw6pF3w']

# %%
review1 = reviews[reviews.business_id == 'vcNAWiLM4dR7D2nwwJ7nCA']

# %%
review1.text
# Out:
# 0    dr. goldberg offers everything i look for in a...
# 1    Unfortunately, the frustration of being Dr. Go...
# 2    Dr. Goldberg has been my doctor for years and ...
# 3    Been going to Dr. Goldberg for over 10 years. ...
# 4    Got a letter in the mail last week that said D...
# 5    I don't know what Dr. Goldberg was like before...
# 6    Top notch doctor in a top notch practice. Can'...
# 7    Dr. Eric Goldberg is a fantastic doctor who ha...
# 8    I'm writing this review to give you a heads up...
# 9    I love Dr. Goldberg. Best doctor I've ever had...
# Name: text, dtype: object

# %%
arr = review1.text.values

# %%
sentences = nltk.sent_tokenize(review1.text[1])

# %%
nltk.download('all')

# %%
sentences
# Out:
# ["Unfortunately, the frustration of being Dr. Goldberg's patient is a repeat of the experience I've had with so many other doctors in NYC -- good doctor, terrible staff.",
#  'It seems that his staff simply never answers the phone.',
#  'It usually takes 2 hours of repeated calling to get an answer.',
#  'Who has time for that or wants to deal with it?',
#  "I have run into this problem with many other doctors and I just don't get it.",
#  "You have office workers, you have patients with medical needs, why isn't anyone answering the phone?",
#  "It's incomprehensible and not work the aggravation.",
#  "It's with regret that I feel that I have to give Dr. Goldberg 2 stars."]

# %%
sentences
# Out:
# ["Unfortunately, the frustration of being Dr. Goldberg's patient is a repeat of the experience I've had with so many other doctors in NYC -- good doctor, terrible staff.",
#  'It seems that his staff simply never answers the phone.',
#  'It usually takes 2 hours of repeated calling to get an answer.',
#  'Who has time for that or wants to deal with it?',
#  "I have run into this problem with many other doctors and I just don't get it.",
#  "You have office workers, you have patients with medical needs, why isn't anyone answering the phone?",
#  "It's incomprehensible and not work the aggravation.",
#  "It's with regret that I feel that I have to give Dr. Goldberg 2 stars."]

# %%
businesses = pd.read_csv('data/yelp_academic_dataset_business.csv')
# Out:
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (1,4,7,14,18,21,27,30,43,49,52,62,64,66,70,84,89,92,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
review2 = reviews[reviews.business_id == 'UsFtqoBl7naz8AVUBZMjQQ']

# %%
review2.text
# Out:
# 10    All the food is great here. But the best thing...
# 11    We checked this place out this past Monday for...
# 12    Wing sauce is like water. Pretty much a lot of...
# 13    Cold cheap beer. Good bar food. Good service. ...
# Name: text, dtype: object

# %%
sentence = review2.text.values[0]

# %%
sentence
# Out:
# 'All the food is great here. But the best thing they have is their wings. Their wings are simply fantastic!!  The "Wet Cajun" are by the best & most popular.  I also like the seasoned salt wings.  Wing Night is Monday & Wednesday night, $0.75 whole wings!\n\nThe dining area is nice. Very family friendly! The bar is very nice is well.  This place is truly a Yinzer\'s dream!!  "Pittsburgh Dad" would love this place n\'at!!'

# %%
# %save notes.py _
# Out:
# The following commands were written to file `notes.py`:
# All the food is great here. But the best thing they have is their wings. Their wings are simply fantastic!!  The "Wet Cajun" are by the best & most popular.  I also like the seasoned salt wings.  Wing Night is Monday & Wednesday night, $0.75 whole wings!
#
# The dining area is nice. Very family friendly! The bar is very nice is well.  This place is truly a Yinzer's dream!!  "Pittsburgh Dad" would love this place n'at!!

# %%
from review_summary import models

# %%
review = models.Review(sentence)

# %%
nltk.download()
# Out:
# showing info http://nltk.github.com/nltk_data/
# True

# %%
nltk.download('maxent_treebank_pos_tagger')

# %%
review

# %%
review.sentences

# %%
for s in review.sentences:
    print s.tags
# Out:
# [('All', 'DT'), ('the', 'DT'), ('food', 'NN'), ('is', 'VBZ'), ('great', 'JJ'), ('here', 'RB'), ('.', '.')]
# [('But', 'CC'), ('the', 'DT'), ('best', 'JJS'), ('thing', 'NN'), ('they', 'PRP'), ('have', 'VBP'), ('is', 'VBZ'), ('their', 'PRP$'), ('wings', 'NNS'), ('.', '.')]
# [('Their', 'PRP$'), ('wings', 'NNS'), ('are', 'VBP'), ('simply', 'RB'), ('fantastic', 'JJ'), ('!', '.'), ('!', '.')]
# [('The', 'DT'), ('``', '``'), ('Wet', 'NNP'), ('Cajun', 'NNP'), ("''", "''"), ('are', 'VBP'), ('by', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('&', 'CC'), ('most', 'JJS'), ('popular', 'JJ'), ('.', '.')]
# [('I', 'PRP'), ('also', 'RB'), ('like', 'IN'), ('the', 'DT'), ('seasoned', 'JJ'), ('salt', 'NN'), ('wings', 'NNS'), ('.', '.')]
# [('Wing', 'VBG'), ('Night', 'NNP'), ('is', 'VBZ'), ('Monday', 'NNP'), ('&', 'CC'), ('Wednesday', 'NNP'), ('night', 'NN'), (',', ','), ('$', '$'), ('0.75', 'CD'), ('whole', 'JJ'), ('wings', 'NNS'), ('!', '.')]
# ...

# %%
s = "Spaghetti Bolognese"

# %%
nltk.pos_tag('milk')
# Out:
# [('m', 'NN'), ('i', 'PRP'), ('l', 'VBP'), ('k', 'NN')]

# %%
s = "In a large pot, heat the oil over medium-high heat. Add the bacon and cook, stirring, until browned and the fat is rendered, 4 to 5 minutes. Add the onions, carrots and celery and cook, stirring, until soft, 4 to 5 minutes. Add the garlic, salt, pepper, bay leaves, thyme, oregano, cinnamon, and nutmeg and cook, stirring, for 30 seconds. Add the beef and sausages, and cook, stirring, until no longer pink, about 5 minutes. Add the tomato paste and cook, stirring, for 1 to 2 minutes. Add the wine and cook, stirring, to deglaze the pan and remove any browned bits sticking to the bottom of the pan, and until half of the liquid is evaporated, about 2 minutes."

# %%
import pandas as pd

# %%
businesses = pd.read_csv('data/yelp_academic_dataset_business.csv')
# Out:
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (1,4,7,14,18,21,27,30,43,49,52,62,64,66,70,84,89,92,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
f = open('data/yelp_academic_dataset_business.csv')
first = f.readline()

# %%
first
# Out:
# 'attributes.Ambience.divey,attributes.Dietary Restrictions.vegan,attributes.Happy Hour,hours.Thursday.open,attributes.Order at Counter,attributes.Hair Types Specialized In.africanamerican,attributes.Hair Types Specialized In.kids,attributes.BYOB,hours.Friday.open,categories,latitude,attributes.Outdoor Seating,attributes.Alcohol,attributes.Ambience.classy,attributes.Payment Types.mastercard,attributes.Parking.lot,business_id,attributes.Ambience.touristy,attributes.Corkage,hours.Tuesday.open,attributes.Good For.brunch,attributes.Payment Types.amex,name,hours.Monday.open,attributes.Waiter Service,attributes.Parking.street,attributes.Ambience.hipster,attributes.BYOB/Corkage,attributes.Hair Types Specialized In.straightperms,attributes.Music.live,attributes.Dietary Restrictions.dairy-free,attributes.Music.background_music,attributes.Good For.dinner,attributes.Good For.breakfast,attributes.Parking.garage,attributes.Music.karaoke,attributes.Good For Dancing,review_count,attributes.Hair Type
# ...

# %%
f.close()

# %%
columns = first.split(',')

# %%
businesses = pd.read_csv('data/yelp_academic_dataset_business.csv', usecols=['business_id', 'categories'])

# %%
businesses.dtypes
# Out:
# categories     object
# business_id    object
# dtype: object

# %%
businesses.iloc[9].categories
# Out:
# "['Burgers', 'Breakfast & Brunch', 'American (Traditional)', 'Restaurants']"

# %%
import re

# %%
re.match(r'Breakfast', "['Breakfast & Brunch', 'Buffets', 'Restaurants']")

# %%
"Restaurants" in "['Breakfast & Brunch', 'Buffets', 'Restaurants']"
# Out:
# True

# %%
restaurants_only = businesses.apply(lambda x: 'Restaurants' in x['categories'], axis=1)

# %%
restaurants_only
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# ...
# 61169     True
# 61170     True
# 61171    False
# 61172     True
# 61173    False
# 61174    False
# 61175     True
# 61176    False
# 61177     True
# 61178     True
# 61179    False
# 61180    False
# 61181    False
# 61182    False
# 61183    False
# Length: 61184, dtype: bool

# %%
restaurants_only = businesses[businesses.apply(lambda x: 'Restaurants' in x['categories'], axis=1)]

# %%
restaurants_only
# Out:
#                                               categories  \
# 4      ['Bars', 'American (New)', 'Nightlife', 'Loung...
# 5      ['Bars', 'American (Traditional)', 'Nightlife'...
# 9      ['Burgers', 'Breakfast & Brunch', 'American (T...
# 11     ['Bars', 'American (Traditional)', 'Nightlife'...
# 12                 ['Breakfast & Brunch', 'Restaurants']
# 13                              ['Cafes', 'Restaurants']
# 15     ['Pubs', 'Irish', 'Nightlife', 'Bars', 'Restau...
# 18                                       ['Restaurants']
# 20                            ['Chinese', 'Restaurants']
# 21     ['Breakfast & Brunch', 'American (Traditional)...
# 23                            ['Restaurants', 'Italian']
# 25               ['Burgers', 'Fast Food', 'Restaurants']
# 26                                       ['Restaurants']
# 29               ['Burgers', 'Fast Food', 'Restaurants']
# 31                  ['Bars', 'Nightlife', 'Restaurants']
# ...

# %%
restaurants_only['business_id'].values
# Out:
# array(['mVHrayjG3uZ_RLHkLj-AMg', 'KayYbHCt-RkbGcPdGOThNg',
#        'wJr6kSA5dchdgOdwH6dZ2w', ..., 'AG3jFaQcABSFF-ry3l5t5g',
#        'LT00Q44xHSFTs1wJPXeS2A', 'qrgod2lrYnxHwNWC_YYTyQ'], dtype=object)

# %%
with open('restaurant_id.txt', 'w+') as f:
    for id in restaurants_only['business_id']:
        f.write(id)
        f.write('\n')

# %%
reviews.head()
# Out:
#                   user_id               review_id  \
# 0  Xqd0DzHaiyRqVH3WRG7hzg  15SdjuK7DmYqUAj6rjGowg
# 1  H1kH6QZV7Le4zqTRNxoZow  RF6UnRTtG7tWMcrO2GEoAg
# 2  zvJCcrpm2yOZrxKffwGQLA  -TsVN230RCkLYKBeLsuz7A
# 3  KBLW4wJA_fwoWmMhiHRVOA  dNocEAyUucjT371NNND41Q
# 4  zvJCcrpm2yOZrxKffwGQLA  ebcN2aqmNUuYNoyvQErgnA
#
#                                                 text  votes.cool  \
# 0  dr. goldberg offers everything i look for in a...           1
# 1  Unfortunately, the frustration of being Dr. Go...           0
# 2  Dr. Goldberg has been my doctor for years and ...           1
# 3  Been going to Dr. Goldberg for over 10 years. ...           0
# 4  Got a letter in the mail last week that said D...           1
#
#               business_id  votes.funny  stars        date    type  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA            0      5  2007-05-17  review
# 1  vcNAWiLM4dR7D2nwwJ7nCA            0      2  2010-03-22  review
# 2  vcNAWiLM4dR7D2nwwJ7nCA            0      4  2012-02-14  review
# ...

# %%
ids = restaurants_only['business_id'].values.tolist()

# %%
reviews_restaurant = reviews[reviews.business_id.isin(ids)]

# %%
reviews_restaurant.head()
# Out:
#                    user_id               review_id  \
# 22  LWbYpcangjBMm4KPxZGOKg  6w6gMZ3iBLGcUM4RBIuifQ
# 23  m1FpV3EAeggaAdfPx0hBRQ  jVVv_DA5mCDB6mediuwHAw
# 24  8fApIAMHn2MZJFUiCQto5Q  3Es8GsjkssusYgeU6_ZVpQ
# 25  uK8tzraOp4M5u3uYrqIBXg  KAkcn7oQP1xX8KsZ-XmktA
# 26  6wvlM5L4_EroGXbnb_92xQ  BZNJkkP0bXnwQ2-sCqat2Q
#
#                                                  text  votes.cool  \
# 22  This place was DELICIOUS!!  My parents saw a r...           0
# 23  Can't miss stop for the best Fish Sandwich in ...           0
# 24  This place should have a lot more reviews - bu...           1
# 25  This place was very good. I found out about Em...           0
# 26  Old school.....traditional "mom 'n pop" qualit...           0
#
#                business_id  votes.funny  stars        date    type  \
# 22  mVHrayjG3uZ_RLHkLj-AMg            0      5  2012-12-01  review
# 23  mVHrayjG3uZ_RLHkLj-AMg            0      5  2013-03-15  review
# ...

# %%
reviews_restaurant.to_csv('data/reviews_restaurant.csv')

# %%
reviews_restaurant[reviews_restaurant.business_id == "mVHrayjG3uZ_RLHkLj-AMg"].text.values
# Out:
# array([ 'This place was DELICIOUS!!  My parents saw a recommendation to visit this place from Rick Sebak\'s "25 Things I Like About Pittsburgh" and he\'s usually pretty accurate.  His recommendations were to try the Reuben, Fish Sandwich and Open-Faced Steak Sandwich.  We went early afternoon for a late lunch today (a Saturday) and were seated right away.  The staff is extremely friendly.  My Mom & I each had the fish sandwich, while my Dad & Brother had a Reuben sandwich.  The fish was very good, but the Reuben was to die for!  Both dishes were massive, and could very easily be shared between two people.  On top of being extremely large portions, it was incredibly affordable.  The giant fish sandwich was $8 and the giant Reuben was $7.50.  Our drinks were always filled and we were checked on several times during the meal.  We will definitely be back!!!  Oh and a bit of advice ahead of time - they take CASH ONLY.  So come prepared, but I\'m pretty sure I saw an ATM there as well.  An
# ...

# %%
r = "All the food is great here. But the best thing they have is their wings. Their wings are simply fantastic!!  The "Wet Cajun" are by the best & most popular.  I also like the seasoned salt wings.  Wing Night is Monday & Wednesday night, $0.75 whole wings!"
# Out:
#   File "<ipython-input-52-d1ce2a4b2e69>", line 1
#     r = "All the food is great here. But the best thing they have is their wings. Their wings are simply fantastic!!  The "Wet Cajun" are by the best & most popular.  I also like the seasoned salt wings.  Wing Night is Monday & Wednesday night, $0.75 whole wings!"
#                                                                                                                              ^
# SyntaxError: invalid syntax

# %%
s = reviews_restaurant[reviews_restaurant.business_id == "mVHrayjG3uZ_RLHkLj-AMg"].text.values[0]

# %%
from review_summary import models

# %%
r = models.Review(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-e200ba9e99f8> in <module>()
# ----> 1 r = models.Review(s)
#
# /Users/bagas/anaconda/envs/ir/project/review_summary/models.py in __init__(self, raw)
#      30     def generate_sentences(self):
#      31         dirty_sentences = nltk.sent_tokenize(self.raw)
# ---> 32         self.sentences = [Sentence(s) for s in dirty_sentences]
#      33
#      34
#
# /Users/bagas/anaconda/envs/ir/project/review_summary/models.py in generate_sentences(self)
#      34
#      35 class Summary(object):
# ---> 36
#      37     def __init__(self, reviews):
#      38         self.reviews = reviews
#
# /Users/bagas/anaconda/envs/ir/project/review_summary/models.py in __init__(self, raw)
#       6     def __init__(self, raw):
#       7         self.raw = raw
# ----> 8         self.generate_tokens()
# ...

# %%
from review_summary import models

# %%
r = models.Review(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-e200ba9e99f8> in <module>()
# ----> 1 r = models.Review(s)
#
# /Users/bagas/anaconda/envs/ir/project/review_summary/models.py in __init__(self, raw)
#      30     def generate_sentences(self):
#      31         dirty_sentences = nltk.sent_tokenize(self.raw)
# ---> 32         self.sentences = [Sentence(s) for s in dirty_sentences]
#      33
#      34
#
# /Users/bagas/anaconda/envs/ir/project/review_summary/models.py in generate_sentences(self)
#      34
#      35 class ReviewSet(object):
# ---> 36
#      37     def __init__(self, raw):
#      38         self.raw = raw
#
# /Users/bagas/anaconda/envs/ir/project/review_summary/models.py in __init__(self, raw)
#       6     def __init__(self, raw):
#       7         self.raw = raw
# ----> 8         self.generate_tokens()
#       9         self.generate_tags()
# ...

# %%
import pandas as pd
import nltk
from review_summary import models

# %%
reviews = pd.read_csv('data/reviews_restaurant.csv')
# Out:
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/pandas/io/parsers.py:1159: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
f = open('data/reviews_restaurant.csv', 'r')

# %%
col = f.readline()

# %%
col
# Out:
# ',user_id,review_id,text,votes.cool,business_id,votes.funny,stars,date,type,votes.useful\n'

# %%
businesses = pd.read_csv('data/yelp_academic_dataset_business.csv', usecols=['business_id', 'categories'])

# %%
businesses.head()
# Out:
#                                           categories             business_id
# 0                    ['Doctors', 'Health & Medical']  vcNAWiLM4dR7D2nwwJ7nCA
# 1                                      ['Nightlife']  UsFtqoBl7naz8AVUBZMjQQ
# 2               ['Active Life', 'Mini Golf', 'Golf']  cE27W9VPgO88Qxe4ol6y_g
# 3  ['Shopping', 'Home Services', 'Internet Servic...  HZdLhv6COCleJMo7nPl-RA
# 4  ['Bars', 'American (New)', 'Nightlife', 'Loung...  mVHrayjG3uZ_RLHkLj-AMg

# %%
businesses = businesses[businesses.apply(lambda x: "Restaurants" in x.categories, axis=1)]

# %%
businesses
# Out:
# Empty DataFrame
# Columns: [categories, business_id]
# Index: []

# %%
businesses.apply(lambda x: "Restaurants" in x.categories, axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# ...
# 61169     True
# 61170     True
# 61171    False
# 61172     True
# 61173    False
# 61174    False
# 61175     True
# 61176    False
# 61177     True
# 61178     True
# 61179    False
# 61180    False
# 61181    False
# 61182    False
# 61183    False
# Length: 61184, dtype: bool

# %%
reviews = pd.read_csv('data/yelp_academic_dataset_review.csv')

# %%
reviews[reviews.isin(businesses.business_id.values.tolist())]
# Out:
#                         user_id review_id text  votes.cool  \
# 0                           NaN       NaN  NaN         NaN
# 1                           NaN       NaN  NaN         NaN
# 2                           NaN       NaN  NaN         NaN
# 3                           NaN       NaN  NaN         NaN
# 4                           NaN       NaN  NaN         NaN
# 5                           NaN       NaN  NaN         NaN
# 6                           NaN       NaN  NaN         NaN
# 7                           NaN       NaN  NaN         NaN
# 8                           NaN       NaN  NaN         NaN
# 9                           NaN       NaN  NaN         NaN
# 10                          NaN       NaN  NaN         NaN
# 11                          NaN       NaN  NaN         NaN
# 12                          NaN       NaN  NaN         NaN
# 13                          NaN       NaN  NaN         NaN
# 14                          NaN       NaN  NaN         NaN
# ...

# %%
reviews.isin(businesses.business_id.values.tolist())
# Out:
#         user_id review_id   text votes.cool business_id votes.funny  stars  \
# 0         False     False  False      False       False       False  False
# 1         False     False  False      False       False       False  False
# 2         False     False  False      False       False       False  False
# 3         False     False  False      False       False       False  False
# 4         False     False  False      False       False       False  False
# 5         False     False  False      False       False       False  False
# 6         False     False  False      False       False       False  False
# 7         False     False  False      False       False       False  False
# 8         False     False  False      False       False       False  False
# 9         False     False  False      False       False       False  False
# 10        False     False  False      False       False       False  False
# ...

# %%
reviews = reviews[reviews.business_id.isin(businesses.business_id.values.tolist())]

# %%
review1 = reviews[reviews.business_id == "mVHrayjG3uZ_RLHkLj-AMg"]

# %%
review1.text[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-51a0aa1711ee> in <module>()
# ----> 1 review1.text[0]
#
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     507     def __getitem__(self, key):
#     508         try:
# --> 509             result = self.index.get_value(self, key)
#     510
#     511             if not np.isscalar(result):
#
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1415
#    1416         try:
# -> 1417             return self._engine.get_value(s, k)
#    1418         except KeyError as e1:
#    1419             if len(self) > 0 and self.inferred_type in ['integer','boolean']:
#
# ...

# %%
review1.iloc[0].text
# Out:
# 'This place was DELICIOUS!!  My parents saw a recommendation to visit this place from Rick Sebak\'s "25 Things I Like About Pittsburgh" and he\'s usually pretty accurate.  His recommendations were to try the Reuben, Fish Sandwich and Open-Faced Steak Sandwich.  We went early afternoon for a late lunch today (a Saturday) and were seated right away.  The staff is extremely friendly.  My Mom & I each had the fish sandwich, while my Dad & Brother had a Reuben sandwich.  The fish was very good, but the Reuben was to die for!  Both dishes were massive, and could very easily be shared between two people.  On top of being extremely large portions, it was incredibly affordable.  The giant fish sandwich was $8 and the giant Reuben was $7.50.  Our drinks were always filled and we were checked on several times during the meal.  We will definitely be back!!!  Oh and a bit of advice ahead of time - they take CASH ONLY.  So come prepared, but I\'m pretty sure I saw an ATM there as well.  And I do b
# ...

# %%
type(review1.iloc[0])
# Out:
# pandas.core.series.Series

# %%
r = models.Review(review1.iloc[0].text)

# %%
for s in r.sentences:
    print s.features
# Out:
# (S This/DT (NP place/NN) was/VBD DELICIOUS/NNP !/. !/.)
# (S
#   My/PRP$
#   parents/NNS
#   saw/VBD
#   a/DT
#   (NP recommendation/NN)
#   to/TO
#   visit/VB
#   this/DT
#   (NP place/NN)
#   from/IN
#   Rick/NNP
#   Sebak/NNP
#   's/POS
#   ``/``
#   25/CD
#   Things/NNS
#   I/PRP
#   Like/VBP
#   About/IN
#   Pittsburgh/NNP
#   ''/''
#   and/CC
#   he/PRP
#   's/VBZ
#   usually/RB
#   pretty/RB
#   accurate/JJ
#   ./.)
# (S
#   His/PRP$
#   recommendations/NNS
#   were/VBD
#   to/TO
#   try/VB
#   the/DT
#   Reuben/NNP
#   ,/,
#   Fish/NNP
#   Sandwich/NNP
#   and/CC
#   Open-Faced/JJ
#   Steak/NNP
#   Sandwich/NNP
#   ./.)
# (S
#   We/PRP
#   went/VBD
#   early/RB
#   (NP afternoon/NN)
#   for/IN
#   a/DT
#   late/JJ
#   (NP lunch/NN today/NN)
#   (/:
#   a/DT
#   Saturday/NNP
#   )/NNP
#   and/CC
#   were/VBD
#   seated/VBN
#   right/RB
#   away/RB
#   ./.)
# (S The/DT (NP staff/NN) is/VBZ extremely/RB friendly/RB ./.)
# (S
#   My/PRP$
#   Mom/NNP
#   &/CC
#   I/PRP
# ...

# %%
"This place was DELICIOUS!!  My parents saw a recommendation to visit this place from Rick Sebak\'s "25 Things I Like About Pittsburgh" and he\'s usually pretty accurate.  His recommendations were to try the Reuben, Fish Sandwich and Open-Faced Steak Sandwich.  We went early afternoon for a late lunch today (a Saturday) and were seated right away.  The staff is extremely friendly.  My Mom & I each had the fish sandwich, while my Dad & Brother had a Reuben sandwich.  The fish was very good, but the Reuben was to die for!  Both dishes were massive, and could very easily be shared between two people.  On top of being extremely large portions, it was incredibly affordable.  The giant fish sandwich was $8 and the giant Reuben was $7.50.  Our drinks were always filled and we were checked on several times during the meal.  We will definitely be back!!!  Oh and a bit of advice ahead of time - they take CASH ONLY.  So come prepared, but I\'m pretty sure I saw an ATM there as well.  And I do believe they are closed on Sundays & Mondays.".lower()
# Out:
#   File "<ipython-input-35-b05f449309e5>", line 1
# ...

# %%
r.sentences[0].raw.lower()
# Out:
# 'this place was delicious!!'

# %%
r = models.Review(review1.iloc[0].text)

# %%
r

# %%
r.sentences[2].raw
# Out:
# 'His recommendations were to try the Reuben, Fish Sandwich and Open-Faced Steak Sandwich.'

# %%
s = models.Sentence('His recommendations were to try the Reuben, Fish Sandwich and Open-Faced Steak Sandwich.')

# %%
s.tags
# Out:
# [('His', 'PRP$'),
#  ('recommendations', 'NNS'),
#  ('were', 'VBD'),
#  ('to', 'TO'),
#  ('try', 'VB'),
#  ('the', 'DT'),
#  ('Reuben', 'NNP'),
#  (',', ','),
#  ('Fish', 'NNP'),
#  ('Sandwich', 'NNP'),
#  ('and', 'CC'),
#  ('Open-Faced', 'JJ'),
#  ('Steak', 'NNP'),
#  ('Sandwich', 'NNP'),
#  ('.', '.')]

# %%
s.raw.lower()
# Out:
# 'his recommendations were to try the reuben, fish sandwich and open-faced steak sandwich.'

# %%
s.lcase
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-e23b65c29991> in <module>()
# ----> 1 s.lcase
#
# AttributeError: 'Sentence' object has no attribute 'lcase'

# %%
from re
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-4b5449716dfd> in <module>()
#       1 grammar = "NP: {<NN>+}"
#       2 cp = nltk.RegexpParser(grammar)
# ----> 3 chunk_tree = cp.parse(nltk.word_tokenize(s.raw.lower()))
#
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/nltk/chunk/regexp.pyc in parse(self, chunk_struct, trace)
#    1200         for i in range(self._loop):
#    1201             for parser in self._stages:
# -> 1202                 chunk_struct = parser.parse(chunk_struct, trace=trace)
#    1203         return chunk_struct
#    1204
#
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/nltk/chunk/regexp.pyc in parse(self, chunk_struct, trace)
#    1015         if trace is None: trace = self._trace
#    1016
# -> 1017         chunkstr = ChunkString(chunk_struct)
#    1018
# ...

# %%
from review_summary import models

# %%
sent = models.Sentence('His recommendations were to try the Reuben, Fish Sandwich and Open-Faced Steak Sandwich.')

# %%
sent.features
# Out:
# /Users/bagas/anaconda/envs/ir/lib/python2.7/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter: [Errno 2] No such file or directory: u'/var/folders/b9/y0b2gcj97854rvykk935x1w40000gn/T/tmpwzE8HD.png'
#   FormatterWarning,
# Tree('S', [('His', 'PRP$'), ('recommendations', 'NNS'), ('were', 'VBD'), ('to', 'TO'), ('try', 'VB'), ('the', 'DT'), ('Reuben', 'NNP'), (',', ','), ('Fish', 'NNP'), ('Sandwich', 'NNP'), ('and', 'CC'), ('Open-Faced', 'JJ'), ('Steak', 'NNP'), ('Sandwich', 'NNP'), ('.', '.')])

# %%
reviews
# Out:
#                         user_id               review_id  \
# 22       LWbYpcangjBMm4KPxZGOKg  6w6gMZ3iBLGcUM4RBIuifQ
# 23       m1FpV3EAeggaAdfPx0hBRQ  jVVv_DA5mCDB6mediuwHAw
# 24       8fApIAMHn2MZJFUiCQto5Q  3Es8GsjkssusYgeU6_ZVpQ
# 25       uK8tzraOp4M5u3uYrqIBXg  KAkcn7oQP1xX8KsZ-XmktA
# 26       6wvlM5L4_EroGXbnb_92xQ  BZNJkkP0bXnwQ2-sCqat2Q
# 27       345nDw0oC-jOcglqxmzweQ  VDTIbR3G5_IPkpXbo2MutA
# 28       u9ULAsnYTdYH65Haj5LMSw  5uyYmniYyIB_wtKtyXDudQ
# 29       pdHC0oAcG7gNdhuFRAUu0Q  zyn_Libz9VZTZ--OdC4-tQ
# 30       tAKjY3bQXH51msJbOHYPmQ  uf61rPucuICXhSPXlZ1hIQ
# 31       Kq8-FUG7d_MT2qRNiNBJnA  xY2gjy49dnpQSB2RTZzqCw
# 32       ay9H1RpjbBkaiXGxfh7LaA  v_uEDbK5fP1UJpkXNPwXpQ
# 33       JbWnXwjLaO1kncUkQOMajg  j8GuxQJ_DQsSfrJNkmcACA
# 34       4-3IU5uUH90m21TWbZhhnA  2xCds3bp0wM6nHMz3H65vg
# 35       bcwr1bFov3PSa1FiGfpc9g  UrukGX1emhSRe2fGdxdVPA
# 36       Sjb5e5-gKoLXueFDMc2R8Q  2_Ru_ASf75kU303rdQjFfQ
# 37       tnArVArlj5usJLZbq9ydbQ  OZ_2Ss5H2bNxnYEcEZC0fA
# ...

# %%
review1 = reviews[reviews.business_id == 'mVHrayjG3uZ_RLHkLj-AMg']

# %%
review1
# Out:
#                    user_id               review_id  \
# 22  LWbYpcangjBMm4KPxZGOKg  6w6gMZ3iBLGcUM4RBIuifQ
# 23  m1FpV3EAeggaAdfPx0hBRQ  jVVv_DA5mCDB6mediuwHAw
# 24  8fApIAMHn2MZJFUiCQto5Q  3Es8GsjkssusYgeU6_ZVpQ
# 25  uK8tzraOp4M5u3uYrqIBXg  KAkcn7oQP1xX8KsZ-XmktA
# 26  6wvlM5L4_EroGXbnb_92xQ  BZNJkkP0bXnwQ2-sCqat2Q
# 27  345nDw0oC-jOcglqxmzweQ  VDTIbR3G5_IPkpXbo2MutA
# 28  u9ULAsnYTdYH65Haj5LMSw  5uyYmniYyIB_wtKtyXDudQ
# 29  pdHC0oAcG7gNdhuFRAUu0Q  zyn_Libz9VZTZ--OdC4-tQ
# 30  tAKjY3bQXH51msJbOHYPmQ  uf61rPucuICXhSPXlZ1hIQ
# 31  Kq8-FUG7d_MT2qRNiNBJnA  xY2gjy49dnpQSB2RTZzqCw
#
#                                                  text  votes.cool  \
# 22  This place was DELICIOUS!!  My parents saw a r...           0
# 23  Can't miss stop for the best Fish Sandwich in ...           0
# 24  This place should have a lot more reviews - bu...           1
# 25  This place was very good. I found out about Em...           0
# 26  Old school.....traditional "mom 'n pop" qualit...           0
# ...

# %%
review1.text.values
# Out:
# array([ 'This place was DELICIOUS!!  My parents saw a recommendation to visit this place from Rick Sebak\'s "25 Things I Like About Pittsburgh" and he\'s usually pretty accurate.  His recommendations were to try the Reuben, Fish Sandwich and Open-Faced Steak Sandwich.  We went early afternoon for a late lunch today (a Saturday) and were seated right away.  The staff is extremely friendly.  My Mom & I each had the fish sandwich, while my Dad & Brother had a Reuben sandwich.  The fish was very good, but the Reuben was to die for!  Both dishes were massive, and could very easily be shared between two people.  On top of being extremely large portions, it was incredibly affordable.  The giant fish sandwich was $8 and the giant Reuben was $7.50.  Our drinks were always filled and we were checked on several times during the meal.  We will definitely be back!!!  Oh and a bit of advice ahead of time - they take CASH ONLY.  So come prepared, but I\'m pretty sure I saw an ATM there as well.  An
# ...

# %%
with open('review_summary/test/reviews.txt', 'w+') as f:
    for review in review1.text.values:
        f.write(review)
        f.write('\n')

# %%
review_text = review1.text.values.tolist()

# %%
import pickle

# %%
import json

# %%
with open('review_summary/test/reviews.json', 'w') as f:
    json.dump(review_text, f)

# %%
reviewSet = models.ReviewSet(review_text)

# %%
review_text[5]
# Out:
# "Seen this restaurant on 25 best places in Pittsburgh with Rick Seback\nack. Went there with my girlfriend she grew up with the owner. She's very nice all employees are super nice service was excellent i had the fish sandwich my girlfriend had the Ruben more than you could possibly eat very reasonable prices. Going back to try the burgers  i heard there enormous and very tasty."

# %%
len(review_text)
# Out:
# 10
